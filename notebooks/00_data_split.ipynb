# %%
import pandas as pd

# %%
df = pd.read_csv(r"..\Data\HouseTS.csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.shape
# Out:
# (884092, 39)

# %%
df.head()
# Out:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2012-03-31            46550.0           217450.0    31.813674
# 1  2012-04-30            61870.0           245000.0    40.723982
# 2  2012-05-31           125500.0           217450.0    63.913043
# 3  2012-06-30           153000.0           189900.0    81.598080
# 4  2012-07-31           165500.0           154000.0    81.598080
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        110.183666        14.0           23.0          44.0       64.0
# 1        130.528256        22.0           29.0          56.0       69.0
# 2        119.919216        24.0           40.0          63.0       60.0
# 3        105.617353        34.0           46.0          50.0       57.0
# 4         83.921175        39.0           49.0          42.0       50.0
#
#    median_dom  avg_sale_to_list  sold_above_list  off_market_in_two_weeks  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884092 entries, 0 to 884091
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   date                          884092 non-null  object
#  1   median_sale_price             884092 non-null  float64
#  2   median_list_price             884092 non-null  float64
#  3   median_ppsf                   884092 non-null  float64
#  4   median_list_ppsf              884092 non-null  float64
#  5   homes_sold                    884092 non-null  float64
#  6   pending_sales                 884092 non-null  float64
#  7   new_listings                  884092 non-null  float64
#  8   inventory                     884092 non-null  float64
#  9   median_dom                    884092 non-null  float64
#  10  avg_sale_to_list              884092 non-null  float64
#  11  sold_above_list               884092 non-null  float64
# ...

# %%
df['date'] = pd.to_datetime(df['date'])
print(df['date'].dt.year.value_counts())
# Out:
# date
# 2013    74712
# 2014    74712
# 2015    74712
# 2016    74712
# 2020    74712
# 2017    74712
# 2018    74712
# 2019    74712
# 2022    74712
# 2021    74712
# 2023    74712
# 2012    62260
# Name: count, dtype: int64

# %% [markdown]
# ### Avoid Leakage
#
#    * Your train set (2012-2019) is `clean` historical training
#
#    * Your eval set (2020-2021) is `unseen` during training, but still used for validation and hyperparameter tuning.
#
#    * Your holdout set (2022-2023) is completely untouched untill the very end.

# %%
# Sort the data by date (Important to avoid shuffling issues)
df = df.sort_values('date')

# %%
# Define cutoff dates
cutoff_data_eval = "2020-01-01"
cutoff_data_holdout = "2022-01-01"

# %%
# Train data before 2020
train_df = df[df['date'] < cutoff_data_eval]

# Validation/Eval data from 2020-2021
eval_df = df[(df['date'] >= cutoff_data_eval) & (df['date'] < cutoff_data_holdout)]

# Holdout data 2022-2023
holdout_df = df[df['date'] >= cutoff_data_holdout]

print("Train shape:", train_df.shape)
print("Eval shape:", eval_df.shape)
print("Holdout shape:", holdout_df.shape)
# Out:
# Train shape: (585244, 39)
# Eval shape: (149424, 39)
# Holdout shape: (149424, 39)

# %%
train_df.tail(2)
# Out:
#              date  median_sale_price  median_list_price  median_ppsf  \
# 302695 2019-12-31           129000.0           124999.0   116.340593
# 467841 2019-12-31           481000.0           505000.0   261.411984
#
#         median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 302695        112.565445       118.0          121.0         133.0       65.0
# 467841        281.692006        48.0           54.0          41.0       42.0
#
#         median_dom  avg_sale_to_list  sold_above_list  \
# 302695        15.0          0.977204         0.245763
# 467841        49.0          0.988881         0.291667
#
#         off_market_in_two_weeks city  zipcode  year  bank  bus  hospital  \
# 302695                 0.371901  DET    48186  2019  11.0  0.0       1.0
# 467841                 0.111111   NY     7009  2019  29.0  0.0       1.0
#
#         mall  park  restaurant  school  station  supermarket  \
# 302695   1.0  52.0        26.0    56.0      0.0         10.0
# ...

# %%
eval_df.head(2)
# Out:
#              date  median_sale_price  median_list_price  median_ppsf  \
# 137976 2020-01-31           184000.0           168450.0   123.333333
# 157714 2020-01-31           140000.0           139000.0    94.691957
#
#         median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 137976        109.899800        35.0           30.0          34.0       37.0
# 157714        111.311054        61.0           81.0          83.0       54.0
#
#         median_dom  avg_sale_to_list  sold_above_list  \
# 137976        50.0          0.954732         0.171429
# 157714        10.0          0.963039         0.098361
#
#         off_market_in_two_weeks city  zipcode  year  bank  bus  hospital  \
# 137976                 0.300000  CHI    60482  2020   3.0  0.0       2.0
# 157714                 0.469136  CIN    41071  2020  35.0  5.0       4.0
#
#         mall   park  restaurant  school  station  supermarket  \
# 137976   0.0   68.0        30.0    60.0      5.0         14.0
# ...

# %%
holdout_df.head(2)
# Out:
#              date  median_sale_price  median_list_price  median_ppsf  \
# 587856 2022-01-31           340000.0           349999.0   189.867865
# 878956 2022-01-31           310000.0           269900.0   243.839836
#
#         median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 587856        195.526649       282.0          287.0         241.0       73.0
# 878956        239.543726        49.0           47.0          43.0        7.0
#
#         median_dom  avg_sale_to_list  sold_above_list  \
# 587856        12.0          0.991177         0.308511
# 878956         6.5          1.006586         0.489796
#
#         off_market_in_two_weeks city  zipcode  year  bank  bus  hospital  \
# 587856                 0.634146  ORL    32771  2022   9.0  0.0       1.0
# 878956                 0.723404  TPA    33778  2022  21.0  0.0       3.0
#
#         mall  park  restaurant  school  station  supermarket  \
# 587856   1.0  56.0        64.0    18.0      4.0          9.0
# ...

# %%
# Save the splitting data
train_df.to_csv("../Data/raw/train.csv" , index=False)
eval_df.to_csv("../Data/raw/eval.csv" , index=False)
holdout_df.to_csv("../Data/raw/holdout.csv" , index=False)
